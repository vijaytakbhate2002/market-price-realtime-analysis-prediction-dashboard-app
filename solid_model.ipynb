# %%
import pandas as pd
import numpy as np
import json
import os

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, StandardScaler

configs = json.load(open("config.json"))
configs
# Out:
# {'row_read_folder_path': 'data/versions/18/csv',
#  'row_write_folder_path': 'data/versions/18/tables'}

# %%
file_names = os.listdir(configs['row_write_folder_path'])
file_names
# Out:
# ['market_prices_20251108-130512.csv',
#  'market_prices_20251108-152423.csv',
#  'market_prices_20251108-152737.csv']

# %%
file_name = os.listdir(configs['row_write_folder_path'])[-1]
full_data_path = os.path.join(configs['row_write_folder_path'], file_name)

# %%
df = pd.read_csv(full_data_path, low_memory=False)
df.head()
# Out:
#             State   District       Market             Commodity  \
# 0  Andhra Pradesh  Anantapur    Anantapur       Ground Nut Seed
# 1  Andhra Pradesh  Anantapur  Dharmavaram  Paddy (Dhan)(Common)
# 2  Andhra Pradesh  Anantapur     Guntakal       Ground Nut Seed
# 3  Andhra Pradesh  Anantapur     Hindupur          Dry Chillies
# 4  Andhra Pradesh  Anantapur     Hindupur        Tamarind Fruit
#
#            Variety   Grade Arrival_Date  Min_Price  Max_Price  Modal_Price  \
# 0  Ground Nut Seed  Medium   2011-01-01     3800.0     3900.0       3850.0
# 1            B P T  Medium   2011-01-01      970.0     1030.0       1000.0
# 2  Ground Nut Seed  Medium   2011-01-01     4300.0     4500.0       4400.0
# 3         2nd Sort  Medium   2011-01-01     2400.0     4000.0       3400.0
# 4       Flower A/c  Medium   2011-01-01     3600.0     4900.0       4250.0
#
#    Commodity_Code
# 0             268
# 1               2
# 2             268
# 3             132
# 4             261

# %%
df.columns
# Out:
# Index(['State', 'District', 'Market', 'Commodity', 'Variety', 'Grade',
#        'Arrival_Date', 'Min_Price', 'Max_Price', 'Modal_Price',
#        'Commodity_Code'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20021522 entries, 0 to 20021521
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   State           object
#  1   District        object
#  2   Market          object
#  3   Commodity       object
#  4   Variety         object
#  5   Grade           object
#  6   Arrival_Date    object
#  7   Min_Price       float64
#  8   Max_Price       float64
#  9   Modal_Price     float64
#  10  Commodity_Code  int64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 1.6+ GB

# %%
df['Arrival_Date'].value_counts().sort_index(ascending=True)
# Out:
# Arrival_Date
# 2011-01-01    2671
# 2011-01-02    1345
# 2011-01-03    2976
# 2011-01-04    2871
# 2011-01-05    3056
#               ...
# 2025-11-02    1734
# 2025-11-03    2384
# 2025-11-04    4114
# 2025-11-05     700
# 2025-11-06       5
# Name: count, Length: 5424, dtype: int64

# %%
cat_cols = df.select_dtypes(include='object').columns
num_cols = df.select_dtypes(exclude='object').columns
print("Cat Columns: ", cat_cols)
print("Num Columns: ", num_cols)
# Out:
# Cat Columns:  Index(['State', 'District', 'Market', 'Commodity', 'Variety', 'Grade',
#        'Arrival_Date'],
#       dtype='object')
# Num Columns:  Index(['Min_Price', 'Max_Price', 'Modal_Price', 'Commodity_Code'], dtype='object')

# %%
from src.data_processing import EncodelData, ScaleData, Imputer
from sklearn.pipeline import Pipeline


pipeline_steps = [
        ("imputer", Imputer(cat_cols=cat_cols, num_cols=num_cols, num_method="mean")),
        ("scaler", ScaleData(num_cols=num_cols, method="minmax")),
        ("encoder", EncodelData(cat_cols=cat_cols, method="label"))
    ]
processing_pipeline_ = Pipeline(pipeline_steps)
processing_pipeline_
# Out:
# Pipeline(steps=[('imputer',
#                  <src.data_processing.Imputer object at 0x0000025E3720E570>),
#                 ('scaler',
#                  <src.data_processing.ScaleData object at 0x0000025E3720E8D0>),
#                 ('encoder',
#                  <src.data_processing.EncodelData object at 0x0000025E3720DC70>)])

# %%
processed_df = processing_pipeline_.fit_transform(df.head(100000))
processed_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 processed_df = processing_pipeline_.fit_transform(df.head(100000))
#       2 processed_df.head()
#
# File D:\Workspace\llmops_learning_repository_lanchain\llmops\projects\market-price-analysis-prediction\dev_env\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File D:\Workspace\llmops_learning_repository_lanchain\llmops\projects\market-price-analysis-prediction\dev_env\Lib\site-packages\sklearn\pipeline.py:719, in Pipeline.fit_transform(self, X, y, **params)
#     680 """Fit the model and transform with the final estimator.
#     681
#     682 Fit all the transformers one after the other and sequentially transform
#    (...)    716     Transformed samples.
#     717 """
#     718 routed_params = self._check_method_params(method="fit_transform", props=params)
# --> 719 Xt = self._fit(X, y, routed_params)
#     721 last_step = self._final_estimator
#     722 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#
# File D:\Workspace\llmops_learning_repository_lanchain\llmops\projects\market-price-analysis-prediction\dev_env\Lib\site-packages\sklearn\pipeline.py:589, in Pipeline._fit(self, X, y, routed_params, raw_params)
#     582 # Fit or load from cache the current transformer
#     583 step_params = self._get_metadata_for_step(
#     584     step_idx=step_idx,
#     585     step_params=routed_params[name],
#     586     all_params=raw_params,
#     587 )
# --> 589 X, fitted_transformer = fit_transform_one_cached(
#     590     cloned_transformer,
#     591     X,
#     592     y,
#     593     weight=None,
#     594     message_clsname="Pipeline",
#     595     message=self._log_message(step_idx),
#     596     params=step_params,
#     597 )
#     598 # Replace the transformer of the step with the fitted
#     599 # transformer. This is necessary when loading the transformer
#     600 # from the cache.
#     601 self.steps[step_idx] = (name, fitted_transformer)
#
# File D:\Workspace\llmops_learning_repository_lanchain\llmops\projects\market-price-analysis-prediction\dev_env\Lib\site-packages\joblib\memory.py:326, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     325 def __call__(self, *args, **kwargs):
# --> 326     return self.func(*args, **kwargs)
#
# File D:\Workspace\llmops_learning_repository_lanchain\llmops\projects\market-price-analysis-prediction\dev_env\Lib\site-packages\sklearn\pipeline.py:1542, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1540         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1541     else:
# -> 1542         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1543             X, **params.get("transform", {})
#    1544         )
#    1546 if weight is None:
#    1547     return res, transformer
#
# File D:\Workspace\llmops_learning_repository_lanchain\llmops\projects\market-price-analysis-prediction\src\data_processing.py:43, in ScaleData.transform(self, X, y)
#      41 X_copy = X.copy()
#      42 scaled_values = self.scaler.transform(X_copy[self.num_cols])
# ---> 43 joblib.dump(self.scaler, processing_configs['scaler_file_path'])
#      44 X_copy[self.num_cols] = pd.DataFrame(
#      45     scaled_values, columns=self.num_cols, index=X_copy.index
#      46 )
#      47 return X_copy
#
# File D:\Workspace\llmops_learning_repository_lanchain\llmops\projects\market-price-analysis-prediction\dev_env\Lib\site-packages\joblib\numpy_pickle.py:599, in dump(value, filename, compress, protocol)
#     597         NumpyPickler(f, protocol=protocol).dump(value)
#     598 elif is_filename:
# --> 599     with open(filename, "wb") as f:
#     600         NumpyPickler(f, protocol=protocol).dump(value)
#     601 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'processing_metrics/scaler.pkl'

# %%
test = df.iloc[0:10]
test
